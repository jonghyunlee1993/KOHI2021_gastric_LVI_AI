# %%
import os
import cv2
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.sampler import Sampler
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

import albumentations as A
from albumentations.pytorch import ToTensor

from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

import warnings
warnings.filterwarnings(action='ignore')

N_EPOCHS = 1000
BATCH_SIZE = 128
LEARNING_RATE = 0.0005
PAITIENCE = 30

IM_HEIGHT = 256
IM_WIDTH = 256

# %%
train_pos, train_neg  = 'data/tumor_classification/train/positive', 'data/tumor_classification/train/negative'
valid_pos, valid_neg  = 'data/tumor_classification/valid/positive', 'data/tumor_classification/valid/negative'
test_pos, test_neg    = 'data/tumor_classification/test/positive', 'data/tumor_classification/test/negative'

def generate_dataframe(path_positive, path_negative):
    df = pd.concat([
            pd.DataFrame({"image": glob.glob(path_positive + "/*.png"), "target": 1}),
            pd.DataFrame({"image": glob.glob(path_negative + "/*.png"), "target": 0}),
        ])
    
    return df

train_df = generate_dataframe(train_pos, train_neg)
valid_df = generate_dataframe(valid_pos, valid_neg)
test_df  = generate_dataframe(test_pos, test_neg)

# %%
train_transforms = A.Compose([
    A.Resize(width=IM_HEIGHT, height=IM_WIDTH, p=1.0),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.ShiftScaleRotate(p=0.5, shift_limit=0.05, scale_limit=0.1, rotate_limit=45),
    A.ElasticTransform(p=0.5),
    A.HueSaturationValue(p=0.5),
    A.RandomBrightness(p=0.5),
    A.Transpose(p=0.5),
    A.GaussNoise(p=0.3),
    A.Blur(p=0.3),
    A.JpegCompression(p=0.3),
    A.Normalize(p=1.0),
    ToTensor(),
])

valid_transforms = A.Compose([
    A.Resize(width=IM_HEIGHT, height=IM_WIDTH, p=1.0),
    A.Normalize(p=1.0),
    ToTensor(),
])


class TumorDataset(Dataset):
    def __init__(self, df, transforms):
        self.df = df
        self.transforms = transforms
        
    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self, idx):
        image  = cv2.imread(self.df.iloc[idx, 0])
        target = self.df.iloc[idx, 1]

        augmented = self.transforms(image=image)
        image = augmented['image']  
        
        return image, target
    
    def get_labels(self):
        return list(self.df.target.values)

    
class BalanceClassSampler(Sampler):
    """Abstraction over data sampler.
    Allows you to create stratified sample on unbalanced classes.
    """

    def __init__(self, labels, mode="downsampling"):
        """
        Args:
            labels (List[int]): list of class label
                for each elem in the datasety
            mode (str): Strategy to balance classes.
                Must be one of [downsampling, upsampling]
        """
        super().__init__(labels)

        labels = np.array(labels)
        samples_per_class = {
            label: (labels == label).sum() for label in set(labels)
        }

        self.lbl2idx = {
            label: np.arange(len(labels))[labels == label].tolist()
            for label in set(labels)
        }

        if isinstance(mode, str):
            assert mode in ["downsampling", "upsampling"]

        if isinstance(mode, int) or mode == "upsampling":
            samples_per_class = (
                mode
                if isinstance(mode, int)
                else max(samples_per_class.values())
            )
        else:
            samples_per_class = min(samples_per_class.values())

        self.labels = labels
        self.samples_per_class = samples_per_class
        self.length = self.samples_per_class * len(set(labels))

    def __iter__(self):
        """
        Yields:
            indices of stratified sample
        """
        indices = []
        for key in sorted(self.lbl2idx):
            replace_ = self.samples_per_class > len(self.lbl2idx[key])
            indices += np.random.choice(
                self.lbl2idx[key], self.samples_per_class, replace=replace_
            ).tolist()
        assert len(indices) == self.length
        np.random.shuffle(indices)

        return iter(indices)

    def __len__(self) -> int:
        """
        Returns:
             length of result sample
        """
        return self.length
    
    
train_dataset = TumorDataset(df=train_df, transforms=train_transforms)
# train_iterator = DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)
train_iterator = DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=False, 
    sampler=BalanceClassSampler(labels=train_dataset.get_labels(), mode='downsampling'))

valid_dataset = TumorDataset(df=valid_df, transforms=valid_transforms)
# valid_iterator = DataLoader(valid_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)
valid_iterator = DataLoader(valid_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=False,
    sampler=BalanceClassSampler(labels=valid_dataset.get_labels(), mode='downsampling'))

test_dataset = TumorDataset(df=test_df, transforms=valid_transforms)
test_iterator = DataLoader(test_dataset, batch_size=1, num_workers=4, shuffle=False)

# %%
device       = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model        = timm.create_model('resnet50', num_classes=2, pretrained=True).to(device)
optimizer    = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
scheduler    = ReduceLROnPlateau(optimizer, 'min')
class_weight = torch.tensor([1.1, 1.0]).to(device)
criterion    = nn.CrossEntropyLoss(weight=class_weight)

for name, param in model.named_parameters():
    param.requires_grad = True
#     if name[:4] == "head":
#         param.requires_grad = True
#     else:
#         param.requires_grad = False

# %%
def train(model, iterator, criterion, optimizer, device=device):  
    model.train()
    epoch_loss = 0
    correct    = 0    
    
    for image, target in iterator:
        optimizer.zero_grad()
        image  = image.to(device)
        target = target.long().to(device)
        
        output = model(image).squeeze()
        
        loss = criterion(output, target)
        loss.backward()
        epoch_loss += loss.item()
        
        pred     = torch.argmax(output, axis=1)
        correct += (pred == target).sum()

        optimizer.step()

    return epoch_loss / len(iterator.dataset), correct / len(iterator.dataset)


@torch.no_grad()
def evaluate(model, iterator, criterion, device=device):
    model.eval()
    epoch_loss = 0
    correct    = 0 
    
    for image, target in iterator:
        image  = image.to(device)
        target = target.long().to(device)

        output = model(image).squeeze()

        loss = criterion(output, target)
        epoch_loss += loss.item()

        pred     = torch.argmax(output, axis=1)
        correct += (pred == target).sum()
            
    return epoch_loss / len(iterator.dataset), correct / len(iterator.dataset)


@torch.no_grad()
def predict(model, iterator, device=device):
    model.eval()
    pred = []
    true = []
    
    for image, target in iterator:
        image  = image.to(device)
        target = target.long().to(device)

        output = model(image)

        pred.append(output.to("cpu").tolist()[0])
        true.append(target.to("cpu").tolist()[0])

    return np.argmax(pred, axis=1), true


def print_train_log(epoch_num, train_loss, valid_loss, train_acc, valid_acc):
    print(f"EPOCH: {epoch_num:04}")
    print(f"Train loss: {round(train_loss, 4)}\tTrain acc : {round(float(train_acc), 4)}\tValid loss: {round(valid_loss, 4)}\tValid acc : {round(float(valid_acc), 4)}")
    
    
def compute_test_metrics(true, pred):
    confusion_mat = confusion_matrix(true, pred)
    accuracy      = accuracy_score(true, pred)
    precision     = precision_score(true, pred)
    recall        = recall_score(true, pred)
    f1            = f1_score(true, pred)
    
    return confusion_mat, accuracy, precision, recall, f1


def print_test_log(epoch_num, accuracy, precision, recall, f1):
    print(f"EPOCH: {epoch_num:04} prediction results ")
    print(f"confusion matrix\n{confusion_mat}")
    print(f"accuracy score  : {round(accuracy, 4)}")
    print(f"precision score : {round(precision, 4)}")
    print(f"recall score    : {round(recall, 4)}")
    print(f"f1 score        : {round(f1, 4)}")

# %%
start_epoch = 0
if len(glob.glob("output/tumor_classifiaction/resnet50/*.txt")) != 0:
    print("load trained model ... ")
    start_epoch = len(glob.glob("output/tumor_classifiaction/resnet50/*.txt")) - 1 
    model.load_state_dict(torch.load('weights/tumor_classification/best_resnet50.pt'))

n_paitience = 0
best_valid_loss = float('inf')

optimizer.zero_grad()
optimizer.step()

for epoch_num in range(start_epoch, N_EPOCHS):
    train_loss, train_acc = train(model, train_iterator, criterion, optimizer, device)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion, device)
    
    scheduler.step(valid_loss)
    
    print_train_log(epoch_num, train_loss, valid_loss, train_acc, valid_acc)
    with open("output/tumor_classification/resnet50/log.txt", "a") as f:
        f.write("epoch: {0:04d} train loss: {1:.4f}, valid loss: {2:.4f}, train Acc: {3:.4f}, valid Acc: {4:.4f}\n".format(epoch_num, train_loss, valid_loss, train_acc, valid_acc))

    if n_paitience < PAITIENCE:
        if best_valid_loss > valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), 'weights/tumor_classification/best_resnet50.pt')
            n_paitience = 0
        elif best_valid_loss <= valid_loss:
            n_paitience += 1
    else:
        print("Early stop!")
        model.load_state_dict(torch.load('weights/tumor_classification/best_resnet50.pt'))
        break
        
    if epoch_num % 1 == 0:
        
        pred, true = predict(model, test_iterator)
        confusion_mat, accuracy, precision, recall, f1 = compute_test_metrics(true, pred)
        
        print_test_log(epoch_num, accuracy, precision, recall, f1)
        with open("output/tumor_classification/resnet50/epoch_{0:04d}_eval_metrics.txt".format(epoch_num), "a") as f:
            f.write("accuracy score: {0:.4f}, precision score: {1:.4f}, recall score: {2:.4f}, f1 score: {3:.4f}\n".format(accuracy, precision, recall, f1))
# Out:
# EPOCH: 0000
# Train loss: 0.0017	Train acc : 0.5242	Valid loss: 0.001	Valid acc : 0.5781
# EPOCH: 0000 prediction results
# confusion matrix
# [[ 738    7]
#  [ 199 1454]]
# accuracy score  : 0.9141
# precision score : 0.9952
# recall score    : 0.8796
# f1 score        : 0.9338
# EPOCH: 0001
# Train loss: 0.0012	Train acc : 0.5576	Valid loss: 0.0008	Valid acc : 0.5834
# EPOCH: 0001 prediction results
# confusion matrix
# [[ 690   55]
#  [  83 1570]]
# accuracy score  : 0.9425
# precision score : 0.9662
# recall score    : 0.9498
# f1 score        : 0.9579
# EPOCH: 0002
# Train loss: 0.0011	Train acc : 0.5625	Valid loss: 0.0006	Valid acc : 0.5939
# EPOCH: 0002 prediction results
# confusion matrix
# [[ 717   28]
#  [  68 1585]]
# accuracy score  : 0.96
# precision score : 0.9826
# recall score    : 0.9589
# f1 score        : 0.9706
# EPOCH: 0003
# Train loss: 0.001	Train acc : 0.573	Valid loss: 0.0006	Valid acc : 0.5912
# EPOCH: 0003 prediction results
# confusion matrix
# [[ 706   39]
#  [  64 1589]]
# accuracy score  : 0.957
# precision score : 0.976
# recall score    : 0.9613
# f1 score        : 0.9686
# EPOCH: 0004
# Train loss: 0.001	Train acc : 0.574	Valid loss: 0.0007	Valid acc : 0.5845
# EPOCH: 0004 prediction results
# confusion matrix
# [[ 738    7]
#  [ 190 1463]]
# accuracy score  : 0.9178
# precision score : 0.9952
# recall score    : 0.8851
# f1 score        : 0.9369
# EPOCH: 0005
# Train loss: 0.0009	Train acc : 0.5731	Valid loss: 0.0008	Valid acc : 0.582
# EPOCH: 0005 prediction results
# confusion matrix
# [[ 666   79]
#  [  32 1621]]
# accuracy score  : 0.9537
# precision score : 0.9535
# recall score    : 0.9806
# f1 score        : 0.9669
# EPOCH: 0006
# Train loss: 0.0009	Train acc : 0.5772	Valid loss: 0.0008	Valid acc : 0.5847
# EPOCH: 0006 prediction results
# confusion matrix
# [[ 669   76]
#  [  20 1633]]
# accuracy score  : 0.96
# precision score : 0.9555
# recall score    : 0.9879
# f1 score        : 0.9714
# EPOCH: 0007
# Train loss: 0.0008	Train acc : 0.5795	Valid loss: 0.0006	Valid acc : 0.5915
# EPOCH: 0007 prediction results
# confusion matrix
# [[ 741    4]
#  [ 138 1515]]
# accuracy score  : 0.9408
# precision score : 0.9974
# recall score    : 0.9165
# f1 score        : 0.9552
# EPOCH: 0008
# Train loss: 0.0009	Train acc : 0.5777	Valid loss: 0.0005	Valid acc : 0.5964
# EPOCH: 0009
# Train loss: 0.0008	Train acc : 0.582	Valid loss: 0.0005	Valid acc : 0.6021
# EPOCH: 0009 prediction results
# confusion matrix
# [[ 710   35]
#  [  39 1614]]
# accuracy score  : 0.9691
# precision score : 0.9788
# recall score    : 0.9764
# f1 score        : 0.9776
# EPOCH: 0010
# Train loss: 0.0008	Train acc : 0.5815	Valid loss: 0.0006	Valid acc : 0.5931
# EPOCH: 0010 prediction results
# confusion matrix
# [[ 725   20]
#  [  78 1575]]
# accuracy score  : 0.9591
# precision score : 0.9875
# recall score    : 0.9528
# f1 score        : 0.9698
# EPOCH: 0011
# Train loss: 0.0008	Train acc : 0.581	Valid loss: 0.0005	Valid acc : 0.5976
# EPOCH: 0011 prediction results
# confusion matrix
# [[ 738    7]
#  [ 101 1552]]
# accuracy score  : 0.955
# precision score : 0.9955
# recall score    : 0.9389
# f1 score        : 0.9664
# EPOCH: 0013
# Train loss: 0.0008	Train acc : 0.5836	Valid loss: 0.0005	Valid acc : 0.6017
# EPOCH: 0013 prediction results
# confusion matrix
# [[ 728   17]
#  [  50 1603]]
# accuracy score  : 0.9721
# precision score : 0.9895
# recall score    : 0.9698
# f1 score        : 0.9795
# EPOCH: 0014 prediction results
# confusion matrix
# [[ 735   10]
#  [  77 1576]]
# accuracy score  : 0.9637
# precision score : 0.9937
# recall score    : 0.9534
# f1 score        : 0.9731
# EPOCH: 0015
# Train loss: 0.0007	Train acc : 0.5871	Valid loss: 0.0005	Valid acc : 0.5999
# EPOCH: 0015 prediction results
# confusion matrix
# [[ 702   43]
#  [  23 1630]]
# accuracy score  : 0.9725
# precision score : 0.9743
# recall score    : 0.9861
# f1 score        : 0.9802
# EPOCH: 0016
# Train loss: 0.0007	Train acc : 0.5846	Valid loss: 0.0005	Valid acc : 0.5945
# EPOCH: 0016 prediction results
# confusion matrix
# [[ 737    8]
#  [ 113 1540]]
# accuracy score  : 0.9495
# precision score : 0.9948
# recall score    : 0.9316
# f1 score        : 0.9622
# EPOCH: 0018
# Train loss: 0.0007	Train acc : 0.5841	Valid loss: 0.0004	Valid acc : 0.6044
# EPOCH: 0018 prediction results
# confusion matrix
# [[ 726   19]
#  [  37 1616]]
# accuracy score  : 0.9766
# precision score : 0.9884
# recall score    : 0.9776
# f1 score        : 0.983
# EPOCH: 0019
# Train loss: 0.0007	Train acc : 0.5843	Valid loss: 0.0004	Valid acc : 0.6054
# EPOCH: 0019 prediction results
# confusion matrix
# [[ 723   22]
#  [  35 1618]]
# accuracy score  : 0.9762
# precision score : 0.9866
# recall score    : 0.9788
# f1 score        : 0.9827
# EPOCH: 0020
# Train loss: 0.0007	Train acc : 0.5888	Valid loss: 0.0004	Valid acc : 0.5997
# EPOCH: 0020 prediction results
# confusion matrix
# [[ 730   15]
#  [  81 1572]]
# accuracy score  : 0.96
# precision score : 0.9905
# recall score    : 0.951
# f1 score        : 0.9704
# EPOCH: 0021
# Train loss: 0.0007	Train acc : 0.5874	Valid loss: 0.0004	Valid acc : 0.5995
# EPOCH: 0021 prediction results
# confusion matrix
# [[ 732   13]
#  [  54 1599]]
# accuracy score  : 0.9721
# precision score : 0.9919
# recall score    : 0.9673
# f1 score        : 0.9795
# EPOCH: 0022
# Train loss: 0.0006	Train acc : 0.5885	Valid loss: 0.0004	Valid acc : 0.6036
# EPOCH: 0022 prediction results
# confusion matrix
# [[ 735   10]
#  [  48 1605]]
# accuracy score  : 0.9758
# precision score : 0.9938
# recall score    : 0.971
# f1 score        : 0.9823
# EPOCH: 0023
# Train loss: 0.0006	Train acc : 0.59	Valid loss: 0.0006	Valid acc : 0.5941
# EPOCH: 0023 prediction results
# confusion matrix
# [[ 742    3]
#  [ 117 1536]]
# accuracy score  : 0.95
# precision score : 0.9981
# recall score    : 0.9292
# f1 score        : 0.9624
# EPOCH: 0024
# Train loss: 0.0007	Train acc : 0.5878	Valid loss: 0.0004	Valid acc : 0.6001
# EPOCH: 0024 prediction results
# confusion matrix
# [[ 720   25]
#  [  44 1609]]
# accuracy score  : 0.9712
# precision score : 0.9847
# recall score    : 0.9734
# f1 score        : 0.979
# EPOCH: 0025
# Train loss: 0.0007	Train acc : 0.5831	Valid loss: 0.0007	Valid acc : 0.5843
# EPOCH: 0025 prediction results
# confusion matrix
# [[ 741    4]
#  [ 161 1492]]
# accuracy score  : 0.9312
# precision score : 0.9973
# recall score    : 0.9026
# f1 score        : 0.9476
# EPOCH: 0026
# Train loss: 0.0006	Train acc : 0.5899	Valid loss: 0.0004	Valid acc : 0.6005
# EPOCH: 0026 prediction results
# confusion matrix
# [[ 741    4]
#  [ 103 1550]]
# accuracy score  : 0.9554
# precision score : 0.9974
# recall score    : 0.9377
# f1 score        : 0.9666
# EPOCH: 0027
# Train loss: 0.0006	Train acc : 0.5887	Valid loss: 0.0004	Valid acc : 0.6034
# EPOCH: 0027 prediction results
# confusion matrix
# [[ 714   31]
#  [  37 1616]]
# accuracy score  : 0.9716
# precision score : 0.9812
# recall score    : 0.9776
# f1 score        : 0.9794
# EPOCH: 0028
# Train loss: 0.0006	Train acc : 0.5897	Valid loss: 0.0004	Valid acc : 0.603
# EPOCH: 0028 prediction results
# confusion matrix
# [[ 736    9]
#  [  57 1596]]
# accuracy score  : 0.9725
# precision score : 0.9944
# recall score    : 0.9655
# f1 score        : 0.9797
# EPOCH: 0029
# Train loss: 0.0006	Train acc : 0.5908	Valid loss: 0.0004	Valid acc : 0.6048
# EPOCH: 0029 prediction results
# confusion matrix
# [[ 725   20]
#  [  42 1611]]
# accuracy score  : 0.9741
# precision score : 0.9877
# recall score    : 0.9746
# f1 score        : 0.9811
# EPOCH: 0030
# Train loss: 0.0006	Train acc : 0.5905	Valid loss: 0.0004	Valid acc : 0.603
# EPOCH: 0030 prediction results
# confusion matrix
# [[ 731   14]
#  [  58 1595]]
# accuracy score  : 0.97
# precision score : 0.9913
# recall score    : 0.9649
# f1 score        : 0.9779
# EPOCH: 0031
# Train loss: 0.0006	Train acc : 0.5924	Valid loss: 0.0005	Valid acc : 0.6023
# EPOCH: 0031 prediction results
# confusion matrix
# [[ 725   20]
#  [  63 1590]]
# accuracy score  : 0.9654
# precision score : 0.9876
# recall score    : 0.9619
# f1 score        : 0.9746
# EPOCH: 0032
# Train loss: 0.0006	Train acc : 0.5915	Valid loss: 0.0005	Valid acc : 0.5972
# EPOCH: 0032 prediction results
# confusion matrix
# [[ 739    6]
#  [ 104 1549]]
# accuracy score  : 0.9541
# precision score : 0.9961
# recall score    : 0.9371
# f1 score        : 0.9657
# EPOCH: 0033
# Train loss: 0.0006	Train acc : 0.5876	Valid loss: 0.0003	Valid acc : 0.605
# EPOCH: 0033 prediction results
# confusion matrix
# [[ 734   11]
#  [  48 1605]]
# accuracy score  : 0.9754
# precision score : 0.9932
# recall score    : 0.971
# f1 score        : 0.982
# EPOCH: 0034
# Train loss: 0.0006	Train acc : 0.5929	Valid loss: 0.0005	Valid acc : 0.5991
# EPOCH: 0034 prediction results
# confusion matrix
# [[ 706   39]
#  [  27 1626]]
# accuracy score  : 0.9725
# precision score : 0.9766
# recall score    : 0.9837
# f1 score        : 0.9801
# EPOCH: 0035
# Train loss: 0.0006	Train acc : 0.5917	Valid loss: 0.0003	Valid acc : 0.6054
# EPOCH: 0035 prediction results
# confusion matrix
# [[ 731   14]
#  [  41 1612]]
# accuracy score  : 0.9771
# precision score : 0.9914
# recall score    : 0.9752
# f1 score        : 0.9832
# EPOCH: 0036
# Train loss: 0.0006	Train acc : 0.5917	Valid loss: 0.0004	Valid acc : 0.6028
# EPOCH: 0036 prediction results
# confusion matrix
# [[ 726   19]
#  [  43 1610]]
# accuracy score  : 0.9741
# precision score : 0.9883
# recall score    : 0.974
# f1 score        : 0.9811
# EPOCH: 0037
# Train loss: 0.0006	Train acc : 0.5919	Valid loss: 0.0004	Valid acc : 0.6044
# EPOCH: 0037 prediction results
# confusion matrix
# [[ 724   21]
#  [  33 1620]]
# accuracy score  : 0.9775
# precision score : 0.9872
# recall score    : 0.98
# f1 score        : 0.9836
# EPOCH: 0038
# Train loss: 0.0006	Train acc : 0.5922	Valid loss: 0.0003	Valid acc : 0.6056
# EPOCH: 0038 prediction results
# confusion matrix
# [[ 732   13]
#  [  34 1619]]
# accuracy score  : 0.9804
# precision score : 0.992
# recall score    : 0.9794
# f1 score        : 0.9857
# EPOCH: 0039
# Train loss: 0.0006	Train acc : 0.5939	Valid loss: 0.0004	Valid acc : 0.605
# EPOCH: 0039 prediction results
# confusion matrix
# [[ 728   17]
#  [  27 1626]]
# accuracy score  : 0.9817
# precision score : 0.9897
# recall score    : 0.9837
# f1 score        : 0.9867
# EPOCH: 0040
# Train loss: 0.0006	Train acc : 0.5939	Valid loss: 0.0004	Valid acc : 0.5999
# EPOCH: 0040 prediction results
# confusion matrix
# [[ 739    6]
#  [  87 1566]]
# accuracy score  : 0.9612
# precision score : 0.9962
# recall score    : 0.9474
# f1 score        : 0.9712
# EPOCH: 0041
# Train loss: 0.0005	Train acc : 0.5942	Valid loss: 0.0004	Valid acc : 0.6058
# EPOCH: 0041 prediction results
# confusion matrix
# [[ 741    4]
#  [  53 1600]]
# accuracy score  : 0.9762
# precision score : 0.9975
# recall score    : 0.9679
# f1 score        : 0.9825
# EPOCH: 0042
# Train loss: 0.0005	Train acc : 0.5963	Valid loss: 0.0004	Valid acc : 0.6067
# EPOCH: 0042 prediction results
# confusion matrix
# [[ 719   26]
#  [  29 1624]]
# accuracy score  : 0.9771
# precision score : 0.9842
# recall score    : 0.9825
# f1 score        : 0.9833
# EPOCH: 0043
# Train loss: 0.0006	Train acc : 0.5952	Valid loss: 0.0003	Valid acc : 0.6065
# EPOCH: 0043 prediction results
# confusion matrix
# [[ 732   13]
#  [  41 1612]]
# accuracy score  : 0.9775
# precision score : 0.992
# recall score    : 0.9752
# f1 score        : 0.9835
# EPOCH: 0044
# Train loss: 0.0006	Train acc : 0.5937	Valid loss: 0.0003	Valid acc : 0.6069
# EPOCH: 0044 prediction results
# confusion matrix
# [[ 735   10]
#  [  47 1606]]
# accuracy score  : 0.9762
# precision score : 0.9938
# recall score    : 0.9716
# f1 score        : 0.9826
# EPOCH: 0045
# Train loss: 0.0005	Train acc : 0.5956	Valid loss: 0.0003	Valid acc : 0.6046
# EPOCH: 0045 prediction results
# confusion matrix
# [[ 721   24]
#  [  24 1629]]
# accuracy score  : 0.98
# precision score : 0.9855
# recall score    : 0.9855
# f1 score        : 0.9855
# EPOCH: 0046
# Train loss: 0.0005	Train acc : 0.5965	Valid loss: 0.0004	Valid acc : 0.6032
# EPOCH: 0046 prediction results
# confusion matrix
# [[ 739    6]
#  [  61 1592]]
# accuracy score  : 0.9721
# precision score : 0.9962
# recall score    : 0.9631
# f1 score        : 0.9794
# EPOCH: 0047
# Train loss: 0.0006	Train acc : 0.5934	Valid loss: 0.0003	Valid acc : 0.6077
# EPOCH: 0047 prediction results
# confusion matrix
# [[ 728   17]
#  [  26 1627]]
# accuracy score  : 0.9821
# precision score : 0.9897
# recall score    : 0.9843
# f1 score        : 0.987
# EPOCH: 0048
# Train loss: 0.0005	Train acc : 0.596	Valid loss: 0.0003	Valid acc : 0.6069
# EPOCH: 0048 prediction results
# confusion matrix
# [[ 734   11]
#  [  51 1602]]
# accuracy score  : 0.9741
# precision score : 0.9932
# recall score    : 0.9691
# f1 score        : 0.981
# EPOCH: 0049
# Train loss: 0.0005	Train acc : 0.5958	Valid loss: 0.0004	Valid acc : 0.6054
# EPOCH: 0049 prediction results
# confusion matrix
# [[ 726   19]
#  [  36 1617]]
# accuracy score  : 0.9771
# precision score : 0.9884
# recall score    : 0.9782
# f1 score        : 0.9833
# EPOCH: 0050
# Train loss: 0.0006	Train acc : 0.5925	Valid loss: 0.0004	Valid acc : 0.604
# EPOCH: 0050 prediction results
# confusion matrix
# [[ 729   16]
#  [  40 1613]]
# accuracy score  : 0.9766
# precision score : 0.9902
# recall score    : 0.9758
# f1 score        : 0.9829
# EPOCH: 0051
# Train loss: 0.0005	Train acc : 0.5975	Valid loss: 0.0004	Valid acc : 0.6015
# EPOCH: 0051 prediction results
# confusion matrix
# [[ 743    2]
#  [  90 1563]]
# accuracy score  : 0.9616
# precision score : 0.9987
# recall score    : 0.9456
# f1 score        : 0.9714
# EPOCH: 0052
# Train loss: 0.0005	Train acc : 0.5967	Valid loss: 0.0003	Valid acc : 0.6056
# EPOCH: 0052 prediction results
# confusion matrix
# [[ 739    6]
#  [  48 1605]]
# accuracy score  : 0.9775
# precision score : 0.9963
# recall score    : 0.971
# f1 score        : 0.9835
# EPOCH: 0053
# Train loss: 0.0005	Train acc : 0.5947	Valid loss: 0.0004	Valid acc : 0.6034
# EPOCH: 0053 prediction results
# confusion matrix
# [[ 717   28]
#  [  23 1630]]
# accuracy score  : 0.9787
# precision score : 0.9831
# recall score    : 0.9861
# f1 score        : 0.9846
# EPOCH: 0054
# Train loss: 0.0005	Train acc : 0.5977	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0054 prediction results
# confusion matrix
# [[ 736    9]
#  [  36 1617]]
# accuracy score  : 0.9812
# precision score : 0.9945
# recall score    : 0.9782
# f1 score        : 0.9863
# EPOCH: 0055
# Train loss: 0.0005	Train acc : 0.5968	Valid loss: 0.0004	Valid acc : 0.6038
# EPOCH: 0055 prediction results
# confusion matrix
# [[ 737    8]
#  [  41 1612]]
# accuracy score  : 0.9796
# precision score : 0.9951
# recall score    : 0.9752
# f1 score        : 0.985
# EPOCH: 0056
# Train loss: 0.0005	Train acc : 0.5962	Valid loss: 0.0004	Valid acc : 0.606
# EPOCH: 0056 prediction results
# confusion matrix
# [[ 728   17]
#  [  29 1624]]
# accuracy score  : 0.9808
# precision score : 0.9896
# recall score    : 0.9825
# f1 score        : 0.986
# EPOCH: 0057
# Train loss: 0.0005	Train acc : 0.5951	Valid loss: 0.0004	Valid acc : 0.6052
# EPOCH: 0057 prediction results
# confusion matrix
# [[ 735   10]
#  [  44 1609]]
# accuracy score  : 0.9775
# precision score : 0.9938
# recall score    : 0.9734
# f1 score        : 0.9835
# EPOCH: 0058
# Train loss: 0.0005	Train acc : 0.5958	Valid loss: 0.0004	Valid acc : 0.6001
# EPOCH: 0058 prediction results
# confusion matrix
# [[ 740    5]
#  [  93 1560]]
# accuracy score  : 0.9591
# precision score : 0.9968
# recall score    : 0.9437
# f1 score        : 0.9695
# EPOCH: 0059
# Train loss: 0.0005	Train acc : 0.5966	Valid loss: 0.0003	Valid acc : 0.6089
# EPOCH: 0059 prediction results
# confusion matrix
# [[ 721   24]
#  [  23 1630]]
# accuracy score  : 0.9804
# precision score : 0.9855
# recall score    : 0.9861
# f1 score        : 0.9858
# EPOCH: 0060
# Train loss: 0.0005	Train acc : 0.5959	Valid loss: 0.0004	Valid acc : 0.6023
# EPOCH: 0060 prediction results
# confusion matrix
# [[ 741    4]
#  [  75 1578]]
# accuracy score  : 0.9671
# precision score : 0.9975
# recall score    : 0.9546
# f1 score        : 0.9756
# EPOCH: 0061
# Train loss: 0.0005	Train acc : 0.5976	Valid loss: 0.0003	Valid acc : 0.6083
# EPOCH: 0061 prediction results
# confusion matrix
# [[ 724   21]
#  [  24 1629]]
# accuracy score  : 0.9812
# precision score : 0.9873
# recall score    : 0.9855
# f1 score        : 0.9864
# EPOCH: 0062
# Train loss: 0.0005	Train acc : 0.5977	Valid loss: 0.0003	Valid acc : 0.6081
# EPOCH: 0062 prediction results
# confusion matrix
# [[ 739    6]
#  [  45 1608]]
# accuracy score  : 0.9787
# precision score : 0.9963
# recall score    : 0.9728
# f1 score        : 0.9844
# EPOCH: 0063
# Train loss: 0.0005	Train acc : 0.5965	Valid loss: 0.0003	Valid acc : 0.6042
# EPOCH: 0063 prediction results
# confusion matrix
# [[ 740    5]
#  [  76 1577]]
# accuracy score  : 0.9662
# precision score : 0.9968
# recall score    : 0.954
# f1 score        : 0.975
# EPOCH: 0064
# Train loss: 0.0005	Train acc : 0.5986	Valid loss: 0.0003	Valid acc : 0.6071
# EPOCH: 0064 prediction results
# confusion matrix
# [[ 732   13]
#  [  30 1623]]
# accuracy score  : 0.9821
# precision score : 0.9921
# recall score    : 0.9819
# f1 score        : 0.9869
# EPOCH: 0065
# Train loss: 0.0005	Train acc : 0.5982	Valid loss: 0.0003	Valid acc : 0.6058
# EPOCH: 0065 prediction results
# confusion matrix
# [[ 736    9]
#  [  49 1604]]
# accuracy score  : 0.9758
# precision score : 0.9944
# recall score    : 0.9704
# f1 score        : 0.9822
# EPOCH: 0066
# Train loss: 0.0004	Train acc : 0.6025	Valid loss: 0.0003	Valid acc : 0.6071
# EPOCH: 0066 prediction results
# confusion matrix
# [[ 734   11]
#  [  19 1634]]
# accuracy score  : 0.9875
# precision score : 0.9933
# recall score    : 0.9885
# f1 score        : 0.9909
# EPOCH: 0067
# Train loss: 0.0004	Train acc : 0.6047	Valid loss: 0.0003	Valid acc : 0.6093
# EPOCH: 0067 prediction results
# confusion matrix
# [[ 734   11]
#  [  17 1636]]
# accuracy score  : 0.9883
# precision score : 0.9933
# recall score    : 0.9897
# f1 score        : 0.9915
# EPOCH: 0068
# Train loss: 0.0004	Train acc : 0.604	Valid loss: 0.0003	Valid acc : 0.6099
# EPOCH: 0068 prediction results
# confusion matrix
# [[ 735   10]
#  [  19 1634]]
# accuracy score  : 0.9879
# precision score : 0.9939
# recall score    : 0.9885
# f1 score        : 0.9912
# EPOCH: 0069
# Train loss: 0.0004	Train acc : 0.6042	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0069 prediction results
# confusion matrix
# [[ 735   10]
#  [  18 1635]]
# accuracy score  : 0.9883
# precision score : 0.9939
# recall score    : 0.9891
# f1 score        : 0.9915
# EPOCH: 0070
# Train loss: 0.0003	Train acc : 0.6046	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0070 prediction results
# confusion matrix
# [[ 737    8]
#  [  19 1634]]
# accuracy score  : 0.9887
# precision score : 0.9951
# recall score    : 0.9885
# f1 score        : 0.9918
# EPOCH: 0071
# Train loss: 0.0003	Train acc : 0.6054	Valid loss: 0.0003	Valid acc : 0.6099
# EPOCH: 0071 prediction results
# confusion matrix
# [[ 734   11]
#  [  17 1636]]
# accuracy score  : 0.9883
# precision score : 0.9933
# recall score    : 0.9897
# f1 score        : 0.9915
# EPOCH: 0072
# Train loss: 0.0003	Train acc : 0.6067	Valid loss: 0.0003	Valid acc : 0.6095
# EPOCH: 0072 prediction results
# confusion matrix
# [[ 735   10]
#  [  19 1634]]
# accuracy score  : 0.9879
# precision score : 0.9939
# recall score    : 0.9885
# f1 score        : 0.9912
# EPOCH: 0073
# Train loss: 0.0003	Train acc : 0.6058	Valid loss: 0.0003	Valid acc : 0.6095
# EPOCH: 0073 prediction results
# confusion matrix
# [[ 736    9]
#  [  15 1638]]
# accuracy score  : 0.99
# precision score : 0.9945
# recall score    : 0.9909
# f1 score        : 0.9927
# EPOCH: 0074
# Train loss: 0.0003	Train acc : 0.6071	Valid loss: 0.0002	Valid acc : 0.6114
# EPOCH: 0074 prediction results
# confusion matrix
# [[ 737    8]
#  [  14 1639]]
# accuracy score  : 0.9908
# precision score : 0.9951
# recall score    : 0.9915
# f1 score        : 0.9933
# EPOCH: 0075
# Train loss: 0.0003	Train acc : 0.606	Valid loss: 0.0003	Valid acc : 0.6108
# EPOCH: 0075 prediction results
# confusion matrix
# [[ 732   13]
#  [  13 1640]]
# accuracy score  : 0.9892
# precision score : 0.9921
# recall score    : 0.9921
# f1 score        : 0.9921
# EPOCH: 0076
# Train loss: 0.0003	Train acc : 0.6078	Valid loss: 0.0003	Valid acc : 0.6099
# EPOCH: 0076 prediction results
# confusion matrix
# [[ 736    9]
#  [  16 1637]]
# accuracy score  : 0.9896
# precision score : 0.9945
# recall score    : 0.9903
# f1 score        : 0.9924
# EPOCH: 0077
# Train loss: 0.0003	Train acc : 0.6075	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0077 prediction results
# confusion matrix
# [[ 737    8]
#  [  19 1634]]
# accuracy score  : 0.9887
# precision score : 0.9951
# recall score    : 0.9885
# f1 score        : 0.9918
# EPOCH: 0078
# Train loss: 0.0003	Train acc : 0.6067	Valid loss: 0.0003	Valid acc : 0.6097
# EPOCH: 0078 prediction results
# confusion matrix
# [[ 736    9]
#  [  20 1633]]
# accuracy score  : 0.9879
# precision score : 0.9945
# recall score    : 0.9879
# f1 score        : 0.9912
# EPOCH: 0079
# Train loss: 0.0003	Train acc : 0.6065	Valid loss: 0.0002	Valid acc : 0.6106
# EPOCH: 0079 prediction results
# confusion matrix
# [[ 738    7]
#  [  22 1631]]
# accuracy score  : 0.9879
# precision score : 0.9957
# recall score    : 0.9867
# f1 score        : 0.9912
# EPOCH: 0080
# Train loss: 0.0003	Train acc : 0.6061	Valid loss: 0.0002	Valid acc : 0.6097
# EPOCH: 0080 prediction results
# confusion matrix
# [[ 735   10]
#  [  14 1639]]
# accuracy score  : 0.99
# precision score : 0.9939
# recall score    : 0.9915
# f1 score        : 0.9927
# EPOCH: 0081
# Train loss: 0.0003	Train acc : 0.6075	Valid loss: 0.0003	Valid acc : 0.6095
# EPOCH: 0081 prediction results
# confusion matrix
# [[ 736    9]
#  [  15 1638]]
# accuracy score  : 0.99
# precision score : 0.9945
# recall score    : 0.9909
# f1 score        : 0.9927
# EPOCH: 0082
# Train loss: 0.0003	Train acc : 0.6074	Valid loss: 0.0003	Valid acc : 0.6099
# EPOCH: 0082 prediction results
# confusion matrix
# [[ 736    9]
#  [  17 1636]]
# accuracy score  : 0.9892
# precision score : 0.9945
# recall score    : 0.9897
# f1 score        : 0.9921
# EPOCH: 0083
# Train loss: 0.0003	Train acc : 0.607	Valid loss: 0.0003	Valid acc : 0.6079
# EPOCH: 0083 prediction results
# confusion matrix
# [[ 737    8]
#  [  16 1637]]
# accuracy score  : 0.99
# precision score : 0.9951
# recall score    : 0.9903
# f1 score        : 0.9927
# EPOCH: 0084
# Train loss: 0.0003	Train acc : 0.6084	Valid loss: 0.0002	Valid acc : 0.6114
# EPOCH: 0084 prediction results
# confusion matrix
# [[ 736    9]
#  [  22 1631]]
# accuracy score  : 0.9871
# precision score : 0.9945
# recall score    : 0.9867
# f1 score        : 0.9906
# EPOCH: 0085
# Train loss: 0.0003	Train acc : 0.6072	Valid loss: 0.0003	Valid acc : 0.6079
# EPOCH: 0085 prediction results
# confusion matrix
# [[ 735   10]
#  [  26 1627]]
# accuracy score  : 0.985
# precision score : 0.9939
# recall score    : 0.9843
# f1 score        : 0.9891
# EPOCH: 0086
# Train loss: 0.0003	Train acc : 0.6086	Valid loss: 0.0003	Valid acc : 0.6089
# EPOCH: 0086 prediction results
# confusion matrix
# [[ 736    9]
#  [  26 1627]]
# accuracy score  : 0.9854
# precision score : 0.9945
# recall score    : 0.9843
# f1 score        : 0.9894
# EPOCH: 0087
# Train loss: 0.0003	Train acc : 0.6081	Valid loss: 0.0002	Valid acc : 0.6112
# EPOCH: 0087 prediction results
# confusion matrix
# [[ 733   12]
#  [  19 1634]]
# accuracy score  : 0.9871
# precision score : 0.9927
# recall score    : 0.9885
# f1 score        : 0.9906
# EPOCH: 0088
# Train loss: 0.0003	Train acc : 0.6096	Valid loss: 0.0002	Valid acc : 0.6104
# EPOCH: 0088 prediction results
# confusion matrix
# [[ 734   11]
#  [  18 1635]]
# accuracy score  : 0.9879
# precision score : 0.9933
# recall score    : 0.9891
# f1 score        : 0.9912
# EPOCH: 0089
# Train loss: 0.0003	Train acc : 0.6091	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0089 prediction results
# confusion matrix
# [[ 737    8]
#  [  20 1633]]
# accuracy score  : 0.9883
# precision score : 0.9951
# recall score    : 0.9879
# f1 score        : 0.9915
# EPOCH: 0090
# Train loss: 0.0003	Train acc : 0.6089	Valid loss: 0.0002	Valid acc : 0.6091
# EPOCH: 0090 prediction results
# confusion matrix
# [[ 732   13]
#  [  14 1639]]
# accuracy score  : 0.9887
# precision score : 0.9921
# recall score    : 0.9915
# f1 score        : 0.9918
# EPOCH: 0091
# Train loss: 0.0003	Train acc : 0.6085	Valid loss: 0.0002	Valid acc : 0.6104
# EPOCH: 0091 prediction results
# confusion matrix
# [[ 735   10]
#  [  14 1639]]
# accuracy score  : 0.99
# precision score : 0.9939
# recall score    : 0.9915
# f1 score        : 0.9927
# EPOCH: 0092
# Train loss: 0.0003	Train acc : 0.6089	Valid loss: 0.0003	Valid acc : 0.6085
# EPOCH: 0092 prediction results
# confusion matrix
# [[ 733   12]
#  [  11 1642]]
# accuracy score  : 0.9904
# precision score : 0.9927
# recall score    : 0.9933
# f1 score        : 0.993
# EPOCH: 0093
# Train loss: 0.0003	Train acc : 0.6084	Valid loss: 0.0002	Valid acc : 0.6104
# EPOCH: 0093 prediction results
# confusion matrix
# [[ 734   11]
#  [  18 1635]]
# accuracy score  : 0.9879
# precision score : 0.9933
# recall score    : 0.9891
# f1 score        : 0.9912
# EPOCH: 0094
# Train loss: 0.0002	Train acc : 0.6088	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0094 prediction results
# confusion matrix
# [[ 735   10]
#  [  19 1634]]
# accuracy score  : 0.9879
# precision score : 0.9939
# recall score    : 0.9885
# f1 score        : 0.9912
# EPOCH: 0095
# Train loss: 0.0003	Train acc : 0.6085	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0095 prediction results
# confusion matrix
# [[ 734   11]
#  [  14 1639]]
# accuracy score  : 0.9896
# precision score : 0.9933
# recall score    : 0.9915
# f1 score        : 0.9924
# EPOCH: 0096
# Train loss: 0.0003	Train acc : 0.6087	Valid loss: 0.0003	Valid acc : 0.6097
# EPOCH: 0096 prediction results
# confusion matrix
# [[ 735   10]
#  [  15 1638]]
# accuracy score  : 0.9896
# precision score : 0.9939
# recall score    : 0.9909
# f1 score        : 0.9924
# EPOCH: 0097
# Train loss: 0.0003	Train acc : 0.6102	Valid loss: 0.0002	Valid acc : 0.6099
# EPOCH: 0097 prediction results
# confusion matrix
# [[ 737    8]
#  [  19 1634]]
# accuracy score  : 0.9887
# precision score : 0.9951
# recall score    : 0.9885
# f1 score        : 0.9918
# EPOCH: 0098
# Train loss: 0.0003	Train acc : 0.606	Valid loss: 0.0002	Valid acc : 0.6106
# EPOCH: 0098 prediction results
# confusion matrix
# [[ 735   10]
#  [  14 1639]]
# accuracy score  : 0.99
# precision score : 0.9939
# recall score    : 0.9915
# f1 score        : 0.9927
# EPOCH: 0099
# Train loss: 0.0003	Train acc : 0.6079	Valid loss: 0.0003	Valid acc : 0.6099
# EPOCH: 0099 prediction results
# confusion matrix
# [[ 736    9]
#  [  14 1639]]
# accuracy score  : 0.9904
# precision score : 0.9945
# recall score    : 0.9915
# f1 score        : 0.993
# EPOCH: 0100
# Train loss: 0.0003	Train acc : 0.6088	Valid loss: 0.0003	Valid acc : 0.6089
# EPOCH: 0100 prediction results
# confusion matrix
# [[ 735   10]
#  [  17 1636]]
# accuracy score  : 0.9887
# precision score : 0.9939
# recall score    : 0.9897
# f1 score        : 0.9918
# EPOCH: 0101
# Train loss: 0.0002	Train acc : 0.6099	Valid loss: 0.0002	Valid acc : 0.612
# EPOCH: 0101 prediction results
# confusion matrix
# [[ 737    8]
#  [  18 1635]]
# accuracy score  : 0.9892
# precision score : 0.9951
# recall score    : 0.9891
# f1 score        : 0.9921
# EPOCH: 0102
# Train loss: 0.0002	Train acc : 0.6098	Valid loss: 0.0002	Valid acc : 0.6116
# EPOCH: 0102 prediction results
# confusion matrix
# [[ 736    9]
#  [  17 1636]]
# accuracy score  : 0.9892
# precision score : 0.9945
# recall score    : 0.9897
# f1 score        : 0.9921
# EPOCH: 0103
# Train loss: 0.0002	Train acc : 0.61	Valid loss: 0.0002	Valid acc : 0.6112
# EPOCH: 0103 prediction results
# confusion matrix
# [[ 735   10]
#  [  16 1637]]
# accuracy score  : 0.9892
# precision score : 0.9939
# recall score    : 0.9903
# f1 score        : 0.9921
# EPOCH: 0104
# Train loss: 0.0003	Train acc : 0.6093	Valid loss: 0.0003	Valid acc : 0.6102
# EPOCH: 0104 prediction results
# confusion matrix
# [[ 736    9]
#  [  18 1635]]
# accuracy score  : 0.9887
# precision score : 0.9945
# recall score    : 0.9891
# f1 score        : 0.9918
# EPOCH: 0105
# Train loss: 0.0003	Train acc : 0.609	Valid loss: 0.0002	Valid acc : 0.6099
# EPOCH: 0105 prediction results
# confusion matrix
# [[ 735   10]
#  [  16 1637]]
# accuracy score  : 0.9892
# precision score : 0.9939
# recall score    : 0.9903
# f1 score        : 0.9921
# EPOCH: 0106
# Train loss: 0.0003	Train acc : 0.6089	Valid loss: 0.0002	Valid acc : 0.6102
# EPOCH: 0106 prediction results
# confusion matrix
# [[ 735   10]
#  [  15 1638]]
# accuracy score  : 0.9896
# precision score : 0.9939
# recall score    : 0.9909
# f1 score        : 0.9924
# EPOCH: 0107
# Train loss: 0.0002	Train acc : 0.6105	Valid loss: 0.0002	Valid acc : 0.6104
# EPOCH: 0107 prediction results
# confusion matrix
# [[ 735   10]
#  [  15 1638]]
# accuracy score  : 0.9896
# precision score : 0.9939
# recall score    : 0.9909
# f1 score        : 0.9924
# EPOCH: 0108
# Train loss: 0.0003	Train acc : 0.6084	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0108 prediction results
# confusion matrix
# [[ 736    9]
#  [  19 1634]]
# accuracy score  : 0.9883
# precision score : 0.9945
# recall score    : 0.9885
# f1 score        : 0.9915
# EPOCH: 0109
# Train loss: 0.0002	Train acc : 0.6095	Valid loss: 0.0003	Valid acc : 0.6097
# EPOCH: 0109 prediction results
# confusion matrix
# [[ 734   11]
#  [  14 1639]]
# accuracy score  : 0.9896
# precision score : 0.9933
# recall score    : 0.9915
# f1 score        : 0.9924
# EPOCH: 0110
# Train loss: 0.0003	Train acc : 0.609	Valid loss: 0.0003	Valid acc : 0.6093
# EPOCH: 0110 prediction results
# confusion matrix
# [[ 736    9]
#  [  16 1637]]
# accuracy score  : 0.9896
# precision score : 0.9945
# recall score    : 0.9903
# f1 score        : 0.9924
# EPOCH: 0111
# Train loss: 0.0002	Train acc : 0.6098	Valid loss: 0.0002	Valid acc : 0.6102
# EPOCH: 0111 prediction results
# confusion matrix
# [[ 734   11]
#  [  13 1640]]
# accuracy score  : 0.99
# precision score : 0.9933
# recall score    : 0.9921
# f1 score        : 0.9927
# EPOCH: 0112
# Train loss: 0.0003	Train acc : 0.6094	Valid loss: 0.0002	Valid acc : 0.6099
# EPOCH: 0112 prediction results
# confusion matrix
# [[ 734   11]
#  [  16 1637]]
# accuracy score  : 0.9887
# precision score : 0.9933
# recall score    : 0.9903
# f1 score        : 0.9918
# EPOCH: 0113
# Train loss: 0.0003	Train acc : 0.6085	Valid loss: 0.0003	Valid acc : 0.6102
# EPOCH: 0113 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0114
# Train loss: 0.0003	Train acc : 0.6092	Valid loss: 0.0002	Valid acc : 0.6116
# EPOCH: 0114 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0115
# Train loss: 0.0002	Train acc : 0.6095	Valid loss: 0.0003	Valid acc : 0.6087
# EPOCH: 0115 prediction results
# confusion matrix
# [[ 735   10]
#  [  14 1639]]
# accuracy score  : 0.99
# precision score : 0.9939
# recall score    : 0.9915
# f1 score        : 0.9927
# EPOCH: 0116
# Train loss: 0.0002	Train acc : 0.6106	Valid loss: 0.0002	Valid acc : 0.6104
# EPOCH: 0116 prediction results
# confusion matrix
# [[ 735   10]
#  [  16 1637]]
# accuracy score  : 0.9892
# precision score : 0.9939
# recall score    : 0.9903
# f1 score        : 0.9921
# EPOCH: 0117
# Train loss: 0.0002	Train acc : 0.6093	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0117 prediction results
# confusion matrix
# [[ 733   12]
#  [  16 1637]]
# accuracy score  : 0.9883
# precision score : 0.9927
# recall score    : 0.9903
# f1 score        : 0.9915
# EPOCH: 0118
# Train loss: 0.0003	Train acc : 0.6094	Valid loss: 0.0002	Valid acc : 0.611
# EPOCH: 0118 prediction results
# confusion matrix
# [[ 733   12]
#  [  15 1638]]
# accuracy score  : 0.9887
# precision score : 0.9927
# recall score    : 0.9909
# f1 score        : 0.9918
# EPOCH: 0119
# Train loss: 0.0003	Train acc : 0.6089	Valid loss: 0.0003	Valid acc : 0.6089
# EPOCH: 0119 prediction results
# confusion matrix
# [[ 733   12]
#  [  15 1638]]
# accuracy score  : 0.9887
# precision score : 0.9927
# recall score    : 0.9909
# f1 score        : 0.9918
# EPOCH: 0120
# Train loss: 0.0002	Train acc : 0.6111	Valid loss: 0.0003	Valid acc : 0.6093
# EPOCH: 0120 prediction results
# confusion matrix
# [[ 734   11]
#  [  15 1638]]
# accuracy score  : 0.9892
# precision score : 0.9933
# recall score    : 0.9909
# f1 score        : 0.9921
# EPOCH: 0121
# Train loss: 0.0003	Train acc : 0.609	Valid loss: 0.0002	Valid acc : 0.611
# EPOCH: 0121 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0122
# Train loss: 0.0003	Train acc : 0.6098	Valid loss: 0.0003	Valid acc : 0.6104
# EPOCH: 0122 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0123
# Train loss: 0.0003	Train acc : 0.6082	Valid loss: 0.0002	Valid acc : 0.6093
# EPOCH: 0123 prediction results
# confusion matrix
# [[ 733   12]
#  [  16 1637]]
# accuracy score  : 0.9883
# precision score : 0.9927
# recall score    : 0.9903
# f1 score        : 0.9915
# EPOCH: 0124
# Train loss: 0.0002	Train acc : 0.6103	Valid loss: 0.0002	Valid acc : 0.6102
# EPOCH: 0124 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0125
# Train loss: 0.0003	Train acc : 0.609	Valid loss: 0.0003	Valid acc : 0.6097
# EPOCH: 0125 prediction results
# confusion matrix
# [[ 733   12]
#  [  13 1640]]
# accuracy score  : 0.9896
# precision score : 0.9927
# recall score    : 0.9921
# f1 score        : 0.9924
# EPOCH: 0126
# Train loss: 0.0003	Train acc : 0.6095	Valid loss: 0.0003	Valid acc : 0.6097
# EPOCH: 0126 prediction results
# confusion matrix
# [[ 735   10]
#  [  17 1636]]
# accuracy score  : 0.9887
# precision score : 0.9939
# recall score    : 0.9897
# f1 score        : 0.9918
# EPOCH: 0127
# Train loss: 0.0002	Train acc : 0.6099	Valid loss: 0.0003	Valid acc : 0.6102
# EPOCH: 0127 prediction results
# confusion matrix
# [[ 734   11]
#  [  16 1637]]
# accuracy score  : 0.9887
# precision score : 0.9933
# recall score    : 0.9903
# f1 score        : 0.9918
# EPOCH: 0128
# Train loss: 0.0003	Train acc : 0.6102	Valid loss: 0.0003	Valid acc : 0.6091
# EPOCH: 0128 prediction results
# confusion matrix
# [[ 735   10]
#  [  16 1637]]
# accuracy score  : 0.9892
# precision score : 0.9939
# recall score    : 0.9903
# f1 score        : 0.9921
# EPOCH: 0129
# Train loss: 0.0003	Train acc : 0.6087	Valid loss: 0.0002	Valid acc : 0.6095
# EPOCH: 0129 prediction results
# confusion matrix
# [[ 733   12]
#  [  15 1638]]
# accuracy score  : 0.9887
# precision score : 0.9927
# recall score    : 0.9909
# f1 score        : 0.9918
# EPOCH: 0130
# Train loss: 0.0002	Train acc : 0.6097	Valid loss: 0.0003	Valid acc : 0.6104
# EPOCH: 0130 prediction results
# confusion matrix
# [[ 735   10]
#  [  17 1636]]
# accuracy score  : 0.9887
# precision score : 0.9939
# recall score    : 0.9897
# f1 score        : 0.9918
# EPOCH: 0131
# Train loss: 0.0002	Train acc : 0.6097	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0131 prediction results
# confusion matrix
# [[ 735   10]
#  [  17 1636]]
# accuracy score  : 0.9887
# precision score : 0.9939
# recall score    : 0.9897
# f1 score        : 0.9918
# EPOCH: 0132
# Train loss: 0.0003	Train acc : 0.6089	Valid loss: 0.0002	Valid acc : 0.6108
# EPOCH: 0132 prediction results
# confusion matrix
# [[ 735   10]
#  [  16 1637]]
# accuracy score  : 0.9892
# precision score : 0.9939
# recall score    : 0.9903
# f1 score        : 0.9921
# EPOCH: 0133
# Train loss: 0.0002	Train acc : 0.6098	Valid loss: 0.0003	Valid acc : 0.6089
# Early stop!

# %%
model.load_state_dict(torch.load('weights/tumor_classification/best_resnet50.pt'))

pred, true = predict(model, test_iterator)
confusion_mat, accuracy, precision, recall, f1 = compute_test_metrics(true, pred)
        
print_test_log(epoch_num, accuracy, precision, recall, f1)
# Out:
# EPOCH: 0133 prediction results
# confusion matrix
# [[ 736    9]
#  [  17 1636]]
# accuracy score  : 0.9892
# precision score : 0.9945
# recall score    : 0.9897
# f1 score        : 0.9921
